# %%
# %load_ext autoreload    #### it has to appear on top of our code
# %autoreload 2


import pandas as pd

url = 'https://raw.githubusercontent.com/yveness7/IronHackIvet/main/Week_2/sharkattack!/sharks.csv'

sharks_df = pd.read_csv(url)

# %%
sharks_df
# Out:
#              Date    Year          Type    Country            State  \
# 0     15 Oct-2023  2023.0    Unprovoked        USA           Hawaii
# 1     13 Oct-2023  2023.0  Questionable        USA       California
# 2     02 Oct-2023  2023.0    Unprovoked        USA           Hawaii
# 3     01 Oct-2023  2023.0    Unprovoked  AUSTRALIA  South Australia
# 4     01 Oct-2023  2023.0    Unprovoked        USA       California
# ...           ...     ...           ...        ...              ...
# 6926          NaN     NaN           NaN        NaN              NaN
# 6927          NaN     NaN           NaN        NaN              NaN
# 6928          NaN     NaN           NaN        NaN              NaN
# 6929          NaN     NaN           NaN        NaN              NaN
# 6930          NaN     NaN           NaN        NaN              NaN
#
#                                               Location  Activity  \
# 0                                   Hanalei Bay, Kauai   Surfing
# 1     Linda Mar, Pacific State Beach, San Mateo County   Surfing
# 2                                           Paia, Maui   Surfing
# 3                                            Beachport  Swimming
# 4                          Wildcat Beach, Marin County  Swimming
# ...                                                ...       ...
# 6926                                               NaN       NaN
# 6927                                               NaN       NaN
# 6928                                               NaN       NaN
# 6929                                               NaN       NaN
# 6930                                               NaN       NaN
#
#                    Name  Sex  Age  ...                 Species   \
# 0          Kevin Kanehe    M   50  ...  Tiger shark, 12' to 15'
# 1                  male    M   52  ...                      NaN
# 2               K. Cole    F   45  ...                      NaN
# 3           Pamela Cook    F   64  ...                      NaN
# 4     Felix Louis N'Jai    M   52  ...                      NaN
# ...                 ...  ...  ...  ...                      ...
# 6926                NaN  NaN  NaN  ...                      NaN
# 6927                NaN  NaN  NaN  ...                      NaN
# 6928                NaN  NaN  NaN  ...                      NaN
# 6929                NaN  NaN  NaN  ...                      NaN
# 6930                NaN  NaN  NaN  ...                      NaN
#
#                              Source  pdf  \
# 0            Kaua'i Now, 10/15/2023  NaN
# 1              CBS News. 10/13/2023  NaN
# 2     The Beat of Hawaii, 10/2/2023  NaN
# 3                    B. Myatt, GSAF  NaN
# 4          SF Chronicle, 10/10/2023  NaN
# ...                             ...  ...
# 6926                            NaN  NaN
# 6927                            NaN  NaN
# 6928                            NaN  NaN
# 6929                            NaN  NaN
# 6930                            NaN  NaN
#
#                                            href formula href Case Number  \
# 0                                                   NaN  NaN         NaN
# 1                                                   NaN  NaN         NaN
# 2                                                   NaN  NaN         NaN
# 3                                                   NaN  NaN         NaN
# 4                                                   NaN  NaN         NaN
# ...                                                 ...  ...         ...
# 6926  http://sharkattackfile.net/spreadsheets/pdf_di...  NaN         NaN
# 6927  http://sharkattackfile.net/spreadsheets/pdf_di...  NaN         NaN
# 6928  http://sharkattackfile.net/spreadsheets/pdf_di...  NaN         NaN
# 6929  http://sharkattackfile.net/spreadsheets/pdf_di...  NaN         NaN
# 6930  http://sharkattackfile.net/spreadsheets/pdf_di...  NaN         NaN
#
#      Case Number.1 original order Unnamed: 21 Unnamed: 22
# 0              NaN            NaN         NaN         NaN
# 1              NaN            NaN         NaN         NaN
# 2              NaN            NaN         NaN         NaN
# 3              NaN            NaN         NaN         NaN
# 4              NaN            NaN         NaN         NaN
# ...            ...            ...         ...         ...
# 6926           NaN            NaN         NaN         NaN
# 6927           NaN            NaN         NaN         NaN
# 6928           NaN            NaN         NaN         NaN
# 6929           NaN            NaN         NaN         NaN
# 6930           NaN            NaN         NaN         NaN
#
# [6931 rows x 23 columns]

# %%
sharks_df.columns
# Out:
# Index(['Date', 'Year', 'Type', 'Country', 'State', 'Location', 'Activity',
#        'Name', 'Sex', 'Age', 'Injury', 'Time', 'Species ', 'Source'],
#       dtype='object')

# %%
sharks_df.drop("pdf", axis='columns',inplace=True)
sharks_df.drop("href formula", axis='columns',inplace=True)
sharks_df.drop("href", axis='columns',inplace=True)
sharks_df.drop("Case Number", axis='columns',inplace=True)
sharks_df.drop("Case Number.1", axis='columns',inplace=True)
sharks_df.drop("original order", axis='columns',inplace=True)
sharks_df.drop("Unnamed: 21", axis='columns',inplace=True)
sharks_df.drop("Unnamed: 22", axis='columns',inplace=True)
sharks_df.drop("Unnamed: 11", axis='columns',inplace=True)

# %%
sharks_df.columns
# Out:
# Index(['Date', 'Year', 'Type', 'Country', 'State', 'Location', 'Activity',
#        'Name', 'Sex', 'Age', 'Injury', 'Time', 'Species ', 'Source'],
#       dtype='object')

# %%
sharks_df.columns = sharks_df.columns.str.lower() #### to change to lower, we should also apply it for the whole dataframe

# %%
sharks_df
# Out:
#              date    year          type    country            state  \
# 0     15 Oct-2023  2023.0    Unprovoked        USA           Hawaii
# 1     13 Oct-2023  2023.0  Questionable        USA       California
# 2     02 Oct-2023  2023.0    Unprovoked        USA           Hawaii
# 3     01 Oct-2023  2023.0    Unprovoked  AUSTRALIA  South Australia
# 4     01 Oct-2023  2023.0    Unprovoked        USA       California
# ...           ...     ...           ...        ...              ...
# 6926          NaN     NaN           NaN        NaN              NaN
# 6927          NaN     NaN           NaN        NaN              NaN
# 6928          NaN     NaN           NaN        NaN              NaN
# 6929          NaN     NaN           NaN        NaN              NaN
# 6930          NaN     NaN           NaN        NaN              NaN
#
#                                               location  activity  \
# 0                                   Hanalei Bay, Kauai   Surfing
# 1     Linda Mar, Pacific State Beach, San Mateo County   Surfing
# 2                                           Paia, Maui   Surfing
# 3                                            Beachport  Swimming
# 4                          Wildcat Beach, Marin County  Swimming
# ...                                                ...       ...
# 6926                                               NaN       NaN
# 6927                                               NaN       NaN
# 6928                                               NaN       NaN
# 6929                                               NaN       NaN
# 6930                                               NaN       NaN
#
#                    name  sex  age                             injury   time  \
# 0          Kevin Kanehe    M   50          Left leg and hand injured  16h00
# 1                  male    M   52   Minor linjury to left lower leg   15h45
# 2               K. Cole    F   45  Minor injury. Shark bit surfboard  13h00
# 3           Pamela Cook    F   64               Bite to foot and leg  07h45
# 4     Felix Louis N'Jai    M   52                 Body not recovered  10h40
# ...                 ...  ...  ...                                ...    ...
# 6926                NaN  NaN  NaN                                NaN    NaN
# 6927                NaN  NaN  NaN                                NaN    NaN
# 6928                NaN  NaN  NaN                                NaN    NaN
# 6929                NaN  NaN  NaN                                NaN    NaN
# 6930                NaN  NaN  NaN                                NaN    NaN
#
#                      species                          source
# 0     Tiger shark, 12' to 15'         Kaua'i Now, 10/15/2023
# 1                         NaN           CBS News. 10/13/2023
# 2                         NaN  The Beat of Hawaii, 10/2/2023
# 3                         NaN                 B. Myatt, GSAF
# 4                         NaN       SF Chronicle, 10/10/2023
# ...                       ...                            ...
# 6926                      NaN                            NaN
# 6927                      NaN                            NaN
# 6928                      NaN                            NaN
# 6929                      NaN                            NaN
# 6930                      NaN                            NaN
#
# [6931 rows x 14 columns]

# %%
sharks_df.duplicated().sum()
# Out:
# 25

# %%
sharks_df.tail(50)
# Out:
#                                                    Date  Year        Type  \
# 6881                                        Before 1927   0.0  Unprovoked
# 6882                                Between 1918 & 1939   0.0  Unprovoked
# 6883                                            No date   0.0  Unprovoked
# 6884                                            No date   0.0  Unprovoked
# 6885                                            No date   0.0  Unprovoked
# 6886                                         1920 -1923   0.0  Unprovoked
# 6887                                        Before 1921   0.0  Unprovoked
# 6888                                        Before 1911   0.0  Unprovoked
# 6889                                        Before 1921   0.0  Unprovoked
# 6890                                        Before 1921   0.0  Unprovoked
# 6891                                        Before 1917   0.0  Unprovoked
# 6892                                 Before 17-Jul-1916   0.0  Unprovoked
# 6893  No date (3 days after preceding incident) & pr...   0.0  Unprovoked
# 6894                                 Before 19-Jul-1913   0.0  Unprovoked
# 6895                                        Before 1911   0.0  Unprovoked
# 6896                                         Circa 1862   0.0  Unprovoked
# 6897                                        Before 1906   0.0  Unprovoked
# 6898                                        Before 1906   0.0  Unprovoked
# 6899                                        Before 1906   0.0  Unprovoked
# 6900                                        Before 1906   0.0  Unprovoked
# 6901                                        Before 1903   0.0  Unprovoked
# 6902                                        Before 1903   0.0  Unprovoked
# 6903                                          1900-1905   0.0  Unprovoked
# 6904                                          1883-1889   0.0  Unprovoked
# 6905                                          1845-1853   0.0  Unprovoked
# 6906                                                NaN   NaN         NaN
# 6907                                                NaN   NaN         NaN
# 6908                                                NaN   NaN         NaN
# 6909                                                NaN   NaN         NaN
# 6910                                                NaN   NaN         NaN
# 6911                                                NaN   NaN         NaN
# 6912                                                NaN   NaN         NaN
# 6913                                                NaN   NaN         NaN
# 6914                                                NaN   NaN         NaN
# 6915                                                NaN   NaN         NaN
# 6916                                                NaN   NaN         NaN
# 6917                                                NaN   NaN         NaN
# 6918                                                NaN   NaN         NaN
# 6919                                                NaN   NaN         NaN
# 6920                                                NaN   NaN         NaN
# 6921                                                NaN   NaN         NaN
# 6922                                                NaN   NaN         NaN
# 6923                                                NaN   NaN         NaN
# 6924                                                NaN   NaN         NaN
# 6925                                                NaN   NaN         NaN
# 6926                                                NaN   NaN         NaN
# 6927                                                NaN   NaN         NaN
# 6928                                                NaN   NaN         NaN
# 6929                                                NaN   NaN         NaN
# 6930                                                NaN   NaN         NaN
#
#                  Country                      State  \
# 6881           AUSTRALIA            New South Wales
# 6882             REUNION                Saint-Denis
# 6883        SOUTH AFRICA      Western Cape Province
# 6884           AUSTRALIA                        NaN
# 6885        SOUTH AFRICA              KwaZulu-Natal
# 6886           AUSTRALIA                 Queensland
# 6887                 USA                    Florida
# 6888             VIETNAM  Ba Ria-Vung Tau  Province
# 6889        SOUTH AFRICA              KwaZulu-Natal
# 6890        SOUTH AFRICA              KwaZulu-Natal
# 6891                FIJI               Moala Island
# 6892                 USA            North Carolina
# 6893        SOUTH AFRICA              KwaZulu-Natal
# 6894        SOUTH AFRICA              KwaZulu-Natal
# 6895               ASIA?                        NaN
# 6896                 USA                     Hawaii
# 6897           AUSTRALIA                        NaN
# 6898           AUSTRALIA                        NaN
# 6899           AUSTRALIA                        NaN
# 6900           AUSTRALIA            New South Wales
# 6901           AUSTRALIA          Western Australia
# 6902           AUSTRALIA          Western Australia
# 6903                 USA             North Carolina
# 6904              PANAMA                        NaN
# 6905  CEYLON (SRI LANKA)           Eastern Province
# 6906                 NaN                        NaN
# 6907                 NaN                        NaN
# 6908                 NaN                        NaN
# 6909                 NaN                        NaN
# 6910                 NaN                        NaN
# 6911                 NaN                        NaN
# 6912                 NaN                        NaN
# 6913                 NaN                        NaN
# 6914                 NaN                        NaN
# 6915                 NaN                        NaN
# 6916                 NaN                        NaN
# 6917                 NaN                        NaN
# 6918                 NaN                        NaN
# 6919                 NaN                        NaN
# 6920                 NaN                        NaN
# 6921                 NaN                        NaN
# 6922                 NaN                        NaN
# 6923                 NaN                        NaN
# 6924                 NaN                        NaN
# 6925                 NaN                        NaN
# 6926                 NaN                        NaN
# 6927                 NaN                        NaN
# 6928                 NaN                        NaN
# 6929                 NaN                        NaN
# 6930                 NaN                        NaN
#
#                                      Location  \
# 6881           Spectacle Island, Port Jackson
# 6882                                Barachois
# 6883                                 Arniston
# 6884                                      NaN
# 6885                                  Durban
# 6886                       Great Barrier Reef
# 6887                 Gadsden Point, Tampa Bay
# 6888                                 Vũng Tàu
# 6889                                  Durban
# 6890                                   Durban
# 6891                                      NaN
# 6892  Somewhere between Hatteras and Beaufort
# 6893                                   Durban
# 6894                                   Durban
# 6895                                      NaN
# 6896                                     Puna
# 6897                                      NaN
# 6898                                      NaN
# 6899                                      NaN
# 6900
# 6901                              Roebuck Bay
# 6902                                      NaN
# 6903                           Ocracoke Inlet
# 6904                     Panama Bay 8ºN, 79ºW
# 6905      Below the English fort, Trincomalee
# 6906                                      NaN
# 6907                                      NaN
# 6908                                      NaN
# 6909                                      NaN
# 6910                                      NaN
# 6911                                      NaN
# 6912                                      NaN
# 6913                                      NaN
# 6914                                      NaN
# 6915                                      NaN
# 6916                                      NaN
# 6917                                      NaN
# 6918                                      NaN
# 6919                                      NaN
# 6920                                      NaN
# 6921                                      NaN
# 6922                                      NaN
# 6923                                      NaN
# 6924                                      NaN
# 6925                                      NaN
# 6926                                      NaN
# 6927                                      NaN
# 6928                                      NaN
# 6929                                      NaN
# 6930                                      NaN
#
#                                                Activity  \
# 6881                                                NaN
# 6882                                           Swimming
# 6883                                             Wading
# 6884                                       Pearl diving
# 6885  Swimming in pool formed by construction of a w...
# 6886                                                NaN
# 6887                                            Fishing
# 6888                      Swimming around anchored ship
# 6889        Crew swimming alongside their anchored ship
# 6890                                 4 men were bathing
# 6891               Wreck of  large double sailing canoe
# 6892                                           Swimming
# 6893                                            Fishing
# 6894                                             Wading
# 6895                                           Swimming
# 6896                                                NaN
# 6897                                            Fishing
# 6898                                            Fishing
# 6899                                            Fishing
# 6900                                           Swimming
# 6901                                             Diving
# 6902                                       Pearl diving
# 6903                                           Swimming
# 6904                                                NaN
# 6905                                           Swimming
# 6906                                                NaN
# 6907                                                NaN
# 6908                                                NaN
# 6909                                                NaN
# 6910                                                NaN
# 6911                                                NaN
# 6912                                                NaN
# 6913                                                NaN
# 6914                                                NaN
# 6915                                                NaN
# 6916                                                NaN
# 6917                                                NaN
# 6918                                                NaN
# 6919                                                NaN
# 6920                                                NaN
# 6921                                                NaN
# 6922                                                NaN
# 6923                                                NaN
# 6924                                                NaN
# 6925                                                NaN
# 6926                                                NaN
# 6927                                                NaN
# 6928                                                NaN
# 6929                                                NaN
# 6930                                                NaN
#
#                                Name  Sex  Age  \
# 6881  male, the Sergeant of Marines    M  NaN
# 6882                            NaN  NaN  NaN
# 6883               Madelaine Dalton    F  NaN
# 6884                    Jaringoorli    M  NaN
# 6885                     Indian boy    M  NaN
# 6886              3 Japanese divers    M  NaN
# 6887                   James Kelley    M  NaN
# 6888                        crewman    M  NaN
# 6889                           male    M  NaN
# 6890                           male    M  NaN
# 6891                     20 Fijians  NaN  NaN
# 6892                "youthful male"    M  NaN
# 6893             a native fisherman    M  NaN
# 6894               a young Scotsman    M  NaN
# 6895                     Mr. Masury    M  NaN
# 6896                   A "chiefess"    F  NaN
# 6897                            boy    M  NaN
# 6898                      fisherman    M  NaN
# 6899                      fisherman    M  NaN
# 6900                       Arab boy    M  NaN
# 6901                           male    M  NaN
# 6902                          Ahmun    M  NaN
# 6903          Coast Guard personnel    M  NaN
# 6904                Jules Patterson    M  NaN
# 6905                           male    M   15
# 6906                            NaN  NaN  NaN
# 6907                            NaN  NaN  NaN
# 6908                            NaN  NaN  NaN
# 6909                            NaN  NaN  NaN
# 6910                            NaN  NaN  NaN
# 6911                            NaN  NaN  NaN
# 6912                            NaN  NaN  NaN
# 6913                            NaN  NaN  NaN
# 6914                            NaN  NaN  NaN
# 6915                            NaN  NaN  NaN
# 6916                            NaN  NaN  NaN
# 6917                            NaN  NaN  NaN
# 6918                            NaN  NaN  NaN
# 6919                            NaN  NaN  NaN
# 6920                            NaN  NaN  NaN
# 6921                            NaN  NaN  NaN
# 6922                            NaN  NaN  NaN
# 6923                            NaN  NaN  NaN
# 6924                            NaN  NaN  NaN
# 6925                            NaN  NaN  NaN
# 6926                            NaN  NaN  NaN
# 6927                            NaN  NaN  NaN
# 6928                            NaN  NaN  NaN
# 6929                            NaN  NaN  NaN
# 6930                            NaN  NaN  NaN
#
#                                                  Injury Time  \
# 6881                                                NaN  NaN
# 6882                                              FATAL  NaN
# 6883                                       Ankle bitten  NaN
# 6884                               Lacerations to thigh  NaN
# 6885                                FATAL, leg severed   NaN
# 6886                                              FATAL  NaN
# 6887                                 2-inch lacerations  NaN
# 6888                                        Foot bitten  NaN
# 6889                                              FATAL  NaN
# 6890                                              FATAL  NaN
# 6891  FATAL, 18 people  were killed by sharks, 2 sur...  NaN
# 6892                                         "Lost leg"  NaN
# 6893  FATAL, body not recovered but shark was caught...  NaN
# 6894                     FATAL, leg stripped of flesh    NaN
# 6895                                       Foot severed  NaN
# 6896                                       Ankle bitten  NaN
# 6897  FATAL, knocked overboard by tail of shark & ca...  NaN
# 6898                                              FATAL  NaN
# 6899                                              FATAL  NaN
# 6900                                              FATAL  NaN
# 6901                                              FATAL  NaN
# 6902                                              FATAL  NaN
# 6903                                              FATAL  NaN
# 6904                                              FATAL  NaN
# 6905  FATAL. "Shark bit him in half, carrying away t...  NaN
# 6906                                                NaN  NaN
# 6907                                                NaN  NaN
# 6908                                                NaN  NaN
# 6909                                                NaN  NaN
# 6910                                                NaN  NaN
# 6911                                                NaN  NaN
# 6912                                                NaN  NaN
# 6913                                                NaN  NaN
# 6914                                                NaN  NaN
# 6915                                                NaN  NaN
# 6916                                                NaN  NaN
# 6917                                                NaN  NaN
# 6918                                                NaN  NaN
# 6919                                                NaN  NaN
# 6920                                                NaN  NaN
# 6921                                                NaN  NaN
# 6922                                                NaN  NaN
# 6923                                                NaN  NaN
# 6924                                                NaN  NaN
# 6925                                                NaN  NaN
# 6926                                                NaN  NaN
# 6927                                                NaN  NaN
# 6928                                                NaN  NaN
# 6929                                                NaN  NaN
# 6930                                                NaN  NaN
#
#                                                Species   \
# 6881                                                NaN
# 6882                                                NaN
# 6883                                                NaN
# 6884                                                NaN
# 6885                                                NaN
# 6886                                                NaN
# 6887                                                NaN
# 6888                                                NaN
# 6889                                                NaN
# 6890                                                NaN
# 6891                                                NaN
# 6892                                                NaN
# 6893                                                NaN
# 6894                                                NaN
# 6895                                                NaN
# 6896                                                NaN
# 6897                                       Blue pointer
# 6898                                       Blue pointer
# 6899                                      Blue pointers
# 6900  Said to involve a grey nurse shark that leapt ...
# 6901                                                NaN
# 6902                                                NaN
# 6903                                                NaN
# 6904                                                NaN
# 6905                                                NaN
# 6906                                                NaN
# 6907                                                NaN
# 6908                                                NaN
# 6909                                                NaN
# 6910                                                NaN
# 6911                                                NaN
# 6912                                                NaN
# 6913                                                NaN
# 6914                                                NaN
# 6915                                                NaN
# 6916                                                NaN
# 6917                                                NaN
# 6918                                                NaN
# 6919                                                NaN
# 6920                                                NaN
# 6921                                                NaN
# 6922                                                NaN
# 6923                                                NaN
# 6924                                                NaN
# 6925                                                NaN
# 6926                                                NaN
# 6927                                                NaN
# 6928                                                NaN
# 6929                                                NaN
# 6930                                                NaN
#
#                                                  Source
# 6881                                          H. Capper
# 6882                                 G. Van Grevelynghe
# 6883              L. Green in Tavern of the Seas, p.182
# 6884                     Adelaide Advertiser, 1/11/1940
# 6885        L. Green in South African Beachcomber, p.97
# 6886                       V.M. Coppleson (1958), p.241
# 6887                                     T. Helm, p.219
# 6888                  Daily Kennebec Journal, 3/27/1911
# 6889  Captain A. Anderson,  Natal Mercury, 12/31/192...
# 6890  Captain A. Anderson,  Natal Mercury, 12/31/192...
# 6891  Fijian Society papers presented April 17, 1918...
# 6892     C. Creswell, GSAF; Wilmington Star, 7/17/1916
# 6893                       Rural New Yorker, 7/19/1913
# 6894                        Rural New Yorker, 7/19/1913
# 6895          Ref. J. T. Dubois in N.Y. Sun, 3/19/1911
# 6896                                   Captain W. Young
# 6897  NY Sun, 9/9/1906, referring to account by Loui...
# 6898  NY Sun, 9/9/1906, referring to account by Loui...
# 6899  NY Sun, 9/9/1906, referring to account by Loui...
# 6900  L. Becke in New York Sun, 9/9/1906; L. Schultz...
# 6901                   H. Taunton; N. Bartlett,  p. 234
# 6902              H. Taunton; N. Bartlett,  pp. 233-234
# 6903               F. Schwartz, p.23; C. Creswell, GSAF
# 6904                                The Sun, 10/20/1938
# 6905                                         S.W. Baker
# 6906                                                NaN
# 6907                                                NaN
# 6908                                                NaN
# 6909                                                NaN
# 6910                                                NaN
# 6911                                                NaN
# 6912                                                NaN
# 6913                                                NaN
# 6914                                                NaN
# 6915                                                NaN
# 6916                                                NaN
# 6917                                                NaN
# 6918                                                NaN
# 6919                                                NaN
# 6920                                                NaN
# 6921                                                NaN
# 6922                                                NaN
# 6923                                                NaN
# 6924                                                NaN
# 6925                                                NaN
# 6926                                                NaN
# 6927                                                NaN
# 6928                                                NaN
# 6929                                                NaN
# 6930                                                NaN

# %%
#pd.Series(data.columns).apply(lambda col: col.lower()) #make columns lower case

# %%
sharks_df.dropna(how='all', inplace=True)

# %%
sharks_df.tail(50)
# Out:
#                                                    date  year          type  \
# 6856                                        Before 1958   0.0    Unprovoked
# 6857                                        Before 1957   0.0    Unprovoked
# 6858                                        Before 1957   0.0      Provoked
# 6859                                        Before 1956   0.0    Unprovoked
# 6860                                        Before 1956   0.0    Unprovoked
# 6861                                    Before Mar-1956   0.0    Unprovoked
# 6862                                        Before 1952   0.0    Unprovoked
# 6863                                          1941-1945   0.0  Sea Disaster
# 6864                         "During the war" 1943-1945   0.0    Unprovoked
# 6865                                   "Before the war"   0.0    Unprovoked
# 6866             Said to be 1941-1945, more likely 1945   0.0    Unprovoked
# 6867                                          1941-1945   0.0    Unprovoked
# 6868                                          1941-1945   0.0    Unprovoked
# 6869                                          1941-1942   0.0    Unprovoked
# 6870                                        1940 - 1950   0.0    Unprovoked
# 6871                                        1940 - 1950   0.0    Unprovoked
# 6872                                        1940 - 1950   0.0    Unprovoked
# 6873                                          1940-1946   0.0  Sea Disaster
# 6874                                        Before 1905   0.0      Provoked
# 6875                                       World War II   0.0  Sea Disaster
# 6876                                       World War II   0.0  Sea Disaster
# 6877                                        Before 1905   0.0    Unprovoked
# 6878                            A few years before 1938   0.0    Watercraft
# 6879                                            No date   0.0    Unprovoked
# 6880                                        Early 1930s   0.0    Unprovoked
# 6881                                        Before 1927   0.0    Unprovoked
# 6882                                Between 1918 & 1939   0.0    Unprovoked
# 6883                                            No date   0.0    Unprovoked
# 6884                                            No date   0.0    Unprovoked
# 6885                                            No date   0.0    Unprovoked
# 6886                                         1920 -1923   0.0    Unprovoked
# 6887                                        Before 1921   0.0    Unprovoked
# 6888                                        Before 1911   0.0    Unprovoked
# 6889                                        Before 1921   0.0    Unprovoked
# 6890                                        Before 1921   0.0    Unprovoked
# 6891                                        Before 1917   0.0    Unprovoked
# 6892                                 Before 17-Jul-1916   0.0    Unprovoked
# 6893  No date (3 days after preceding incident) & pr...   0.0    Unprovoked
# 6894                                 Before 19-Jul-1913   0.0    Unprovoked
# 6895                                        Before 1911   0.0    Unprovoked
# 6896                                         Circa 1862   0.0    Unprovoked
# 6897                                        Before 1906   0.0    Unprovoked
# 6898                                        Before 1906   0.0    Unprovoked
# 6899                                        Before 1906   0.0    Unprovoked
# 6900                                        Before 1906   0.0    Unprovoked
# 6901                                        Before 1903   0.0    Unprovoked
# 6902                                        Before 1903   0.0    Unprovoked
# 6903                                          1900-1905   0.0    Unprovoked
# 6904                                          1883-1889   0.0    Unprovoked
# 6905                                          1845-1853   0.0    Unprovoked
#
#                   country                              state  \
# 6856                INDIA                        Maharashtra
# 6857            NICARAGUA       Lake Nicaragua (fresh water)
# 6858                 CUBA                    Havana Province
# 6859     MARSHALL ISLANDS                       Bikini Atoll
# 6860             KIRIBATI                    Phoenix Islands
# 6861  NORTH PACIFIC OCEAN                                NaN
# 6862             KIRIBATI                    Gilbert Islands
# 6863                  NaN                                NaN
# 6864      SOLOMON ISLANDS                        New Georgia
# 6865            AUSTRALIA                      Torres Strait
# 6866                 IRAN                 Khuzestan Province
# 6867                 IRAN                 Khuzestan Province
# 6868                 IRAN                 Khuzestan Province
# 6869                 IRAQ                             Basrah
# 6870         SAUDI ARABIA                   Eastern Province
# 6871         SAUDI ARABIA                   Eastern Province
# 6872         SAUDI ARABIA                   Eastern Province
# 6873        PACIFIC OCEAN                                NaN
# 6874                BURMA                                NaN
# 6875     PAPUA NEW GUINEA  Between New Ireland & New Britain
# 6876     PAPUA NEW GUINEA                    Madang Province
# 6877                BURMA                                NaN
# 6878                ITALY                       Adriatic Sea
# 6879               GREECE                 Dodecanese Islands
# 6880               BELIZE                                NaN
# 6881            AUSTRALIA                    New South Wales
# 6882              REUNION                        Saint-Denis
# 6883         SOUTH AFRICA              Western Cape Province
# 6884            AUSTRALIA                                NaN
# 6885         SOUTH AFRICA                      KwaZulu-Natal
# 6886            AUSTRALIA                         Queensland
# 6887                  USA                            Florida
# 6888              VIETNAM          Ba Ria-Vung Tau  Province
# 6889         SOUTH AFRICA                      KwaZulu-Natal
# 6890         SOUTH AFRICA                      KwaZulu-Natal
# 6891                 FIJI                       Moala Island
# 6892                  USA                    North Carolina
# 6893         SOUTH AFRICA                      KwaZulu-Natal
# 6894         SOUTH AFRICA                      KwaZulu-Natal
# 6895                ASIA?                                NaN
# 6896                  USA                             Hawaii
# 6897            AUSTRALIA                                NaN
# 6898            AUSTRALIA                                NaN
# 6899            AUSTRALIA                                NaN
# 6900            AUSTRALIA                    New South Wales
# 6901            AUSTRALIA                  Western Australia
# 6902            AUSTRALIA                  Western Australia
# 6903                  USA                     North Carolina
# 6904               PANAMA                                NaN
# 6905   CEYLON (SRI LANKA)                   Eastern Province
#
#                                          location  \
# 6856                       Malwan, near Ratnagiri
# 6857               A village  north of San Carlos
# 6858                                      Cojimar
# 6859                                          NaN
# 6860                                Canton Island
# 6861                                  Wake Island
# 6862                                      Nonouti
# 6863                                          NaN
# 6864                 Munda Island, Roviana Lagoon
# 6865                             Thursday Island?
# 6866                    Ahvaz, on the Karun River
# 6867                    Ahvaz, on the Karun River
# 6868                    Ahvaz, on the Karun River
# 6869  Shatt-el Arab River near a small boat stand
# 6870          East of the Ras Tanura-Jubail area
# 6871          East of the Ras Tanura-Jubail area
# 6872          East of the Ras Tanura-Jubail area
# 6873                                          NaN
# 6874                                          NaN
# 6875                         St. George’s Channel
# 6876                                      Off Lae
# 6877                                          NaN
# 6878                                          NaN
# 6879                                  Symi Island
# 6880                                          NaN
# 6881               Spectacle Island, Port Jackson
# 6882                                    Barachois
# 6883                                     Arniston
# 6884                                          NaN
# 6885                                      Durban
# 6886                           Great Barrier Reef
# 6887                     Gadsden Point, Tampa Bay
# 6888                                     Vũng Tàu
# 6889                                      Durban
# 6890                                       Durban
# 6891                                          NaN
# 6892      Somewhere between Hatteras and Beaufort
# 6893                                       Durban
# 6894                                       Durban
# 6895                                          NaN
# 6896                                         Puna
# 6897                                          NaN
# 6898                                          NaN
# 6899                                          NaN
# 6900
# 6901                                  Roebuck Bay
# 6902                                          NaN
# 6903                               Ocracoke Inlet
# 6904                         Panama Bay 8ºN, 79ºW
# 6905          Below the English fort, Trincomalee
#
#                                                activity  \
# 6856                                                NaN
# 6857  Lashing logs together when he fell into the water
# 6858                   Shark fishing, knocked overboard
# 6859                                           Swimming
# 6860                                             Diving
# 6861                Fishing, wading with string of fish
# 6862                                                NaN
# 6863         A group of survivors on a raft for 17-days
# 6864                               Floating on his back
# 6865                                        Free diving
# 6866                        Fishing in ankle-deep water
# 6867                                                NaN
# 6868  Standing, washing rear wheels of his ambulance...
# 6869                                           Swimming
# 6870                                             Diving
# 6871                                             Diving
# 6872                                             Diving
# 6873                                                NaN
# 6874      Carrying a supposedly dead shark by its mouth
# 6875                             Spent 8 days in dinghy
# 6876       Aircraft ditched in the sea, swimming ashore
# 6877                                            Bathing
# 6878                                Wooden fishing boat
# 6879                                      Sponge diving
# 6880                                           Standing
# 6881                                                NaN
# 6882                                           Swimming
# 6883                                             Wading
# 6884                                       Pearl diving
# 6885  Swimming in pool formed by construction of a w...
# 6886                                                NaN
# 6887                                            Fishing
# 6888                      Swimming around anchored ship
# 6889        Crew swimming alongside their anchored ship
# 6890                                 4 men were bathing
# 6891               Wreck of  large double sailing canoe
# 6892                                           Swimming
# 6893                                            Fishing
# 6894                                             Wading
# 6895                                           Swimming
# 6896                                                NaN
# 6897                                            Fishing
# 6898                                            Fishing
# 6899                                            Fishing
# 6900                                           Swimming
# 6901                                             Diving
# 6902                                       Pearl diving
# 6903                                           Swimming
# 6904                                                NaN
# 6905                                           Swimming
#
#                                                    name  sex       age  \
# 6856                                               male    M       NaN
# 6857                                          an Indian    M       NaN
# 6858                                         Sandrillio    M        50
# 6859                                               male    M       NaN
# 6860                                       Dusty Rhodes    M       NaN
# 6861                                               male    M       NaN
# 6862                               Gilbertese fisherman    M       NaN
# 6863                                                 C.  NaN       NaN
# 6864                                      American male    M       NaN
# 6865                                           Mortakee    M       NaN
# 6866                                   an old fisherman    M       NaN
# 6867                                  a local dignitary    M       NaN
# 6868                                  I.A.S. C. driver     M       NaN
# 6869                                               male    M  13 or 14
# 6870                                      a pearl diver    M       NaN
# 6871                                a fisherman / diver    M       NaN
# 6872                                      a pearl diver    M       NaN
# 6873  8 US airmen in the water, 1 was bitten by a shark    M       NaN
# 6874                                                boy    M       NaN
# 6875                                              pilot    M       NaN
# 6876                                               male    M       NaN
# 6877                                               male    M       NaN
# 6878                         Occupant:     Mr. Maciotta    M       NaN
# 6879                                    Psarofa-gomenes    M       NaN
# 6880                                          a servant    M        16
# 6881                      male, the Sergeant of Marines    M       NaN
# 6882                                                NaN  NaN       NaN
# 6883                                   Madelaine Dalton    F       NaN
# 6884                                        Jaringoorli    M       NaN
# 6885                                         Indian boy    M       NaN
# 6886                                  3 Japanese divers    M       NaN
# 6887                                       James Kelley    M       NaN
# 6888                                            crewman    M       NaN
# 6889                                               male    M       NaN
# 6890                                               male    M       NaN
# 6891                                         20 Fijians  NaN       NaN
# 6892                                    "youthful male"    M       NaN
# 6893                                 a native fisherman    M       NaN
# 6894                                   a young Scotsman    M       NaN
# 6895                                         Mr. Masury    M       NaN
# 6896                                       A "chiefess"    F       NaN
# 6897                                                boy    M       NaN
# 6898                                          fisherman    M       NaN
# 6899                                          fisherman    M       NaN
# 6900                                           Arab boy    M       NaN
# 6901                                               male    M       NaN
# 6902                                              Ahmun    M       NaN
# 6903                              Coast Guard personnel    M       NaN
# 6904                                    Jules Patterson    M       NaN
# 6905                                               male    M        15
#
#                                                  injury            time  \
# 6856                                              FATAL             NaN
# 6857                                FATAL, leg severed              NaN
# 6858               FATAL, hip bitten  PROVOKED INCIDENT             NaN
# 6859                                    Buttocks bitten             NaN
# 6860                                          No injury             NaN
# 6861                                           Survived             NaN
# 6862                                              FATAL             NaN
# 6863  FATAL, shark leapt into raft and bit the man w...  Late afternoon
# 6864                                     Buttock bitten             NaN
# 6865                                        Head bitten             NaN
# 6866                  FATAL, foot lacerated & crushed               NaN
# 6867  FATAL, femoral artery severed, died 12 days la...             NaN
# 6868  FATAL, fell into water when shark seized his r...             NaN
# 6869      FATAL, left leg bitten with severe blood loss       Afternoon
# 6870                              FATAL, died of sepsis             NaN
# 6871                                    Buttocks bitten             NaN
# 6872               Foot lacerated, surgically amputated             NaN
# 6873                                              FATAL             NaN
# 6874  4 fingers severed by 'dead' shark. PROVOKED AC...             NaN
# 6875  No injury, but shark removed the heel & part o...             NaN
# 6876                                   Shark bumped him             NaN
# 6877                                          Fatal x 2             NaN
# 6878         No injury to occupant; shark capsized boat             NaN
# 6879                                        Head bitten             NaN
# 6880                                              FATAL             NaN
# 6881                                                NaN             NaN
# 6882                                              FATAL             NaN
# 6883                                       Ankle bitten             NaN
# 6884                               Lacerations to thigh             NaN
# 6885                                FATAL, leg severed              NaN
# 6886                                              FATAL             NaN
# 6887                                 2-inch lacerations             NaN
# 6888                                        Foot bitten             NaN
# 6889                                              FATAL             NaN
# 6890                                              FATAL             NaN
# 6891  FATAL, 18 people  were killed by sharks, 2 sur...             NaN
# 6892                                         "Lost leg"             NaN
# 6893  FATAL, body not recovered but shark was caught...             NaN
# 6894                     FATAL, leg stripped of flesh               NaN
# 6895                                       Foot severed             NaN
# 6896                                       Ankle bitten             NaN
# 6897  FATAL, knocked overboard by tail of shark & ca...             NaN
# 6898                                              FATAL             NaN
# 6899                                              FATAL             NaN
# 6900                                              FATAL             NaN
# 6901                                              FATAL             NaN
# 6902                                              FATAL             NaN
# 6903                                              FATAL             NaN
# 6904                                              FATAL             NaN
# 6905  FATAL. "Shark bit him in half, carrying away t...             NaN
#
#                                                species   \
# 6856                                                NaN
# 6857  Bull shark caught, leg recovered & buried besi...
# 6858                                                NaN
# 6859                                                NaN
# 6860                                                NaN
# 6861                                                NaN
# 6862                                                NaN
# 6863                                   1.2 m [4'] shark
# 6864                                                NaN
# 6865                                                NaN
# 6866                                                NaN
# 6867                                                NaN
# 6868                                                NaN
# 6869                                         Bull shark
# 6870                             "a black-tipped shark"
# 6871                                           6' shark
# 6872                                                NaN
# 6873                                                NaN
# 6874                                                NaN
# 6875                                                NaN
# 6876                                                NaN
# 6877                                                NaN
# 6878                                        White shark
# 6879                                                NaN
# 6880                                    12' tiger shark
# 6881                                                NaN
# 6882                                                NaN
# 6883                                                NaN
# 6884                                                NaN
# 6885                                                NaN
# 6886                                                NaN
# 6887                                                NaN
# 6888                                                NaN
# 6889                                                NaN
# 6890                                                NaN
# 6891                                                NaN
# 6892                                                NaN
# 6893                                                NaN
# 6894                                                NaN
# 6895                                                NaN
# 6896                                                NaN
# 6897                                       Blue pointer
# 6898                                       Blue pointer
# 6899                                      Blue pointers
# 6900  Said to involve a grey nurse shark that leapt ...
# 6901                                                NaN
# 6902                                                NaN
# 6903                                                NaN
# 6904                                                NaN
# 6905                                                NaN
#
#                                                  source
# 6856                       V.M. Coppleson (1958), p.261
# 6857                                F. Poli, pp.150-153
# 6858                              F. Poli, pp.75, 81-83
# 6859                                         J.E. Lasch
# 6860  J. Oetzel, Skin Diver Magazine, March 1956, p.19
# 6861  J. Oetzel, Skin Diver Magazine, March 1956, p.19
# 6862                               Grimble, pp. 142-143
# 6863         G.A. Llano in Airmen Against the Sea, p.69
# 6864  W. Chapman (1949) Fishing in Troubled Waters, ...
# 6865                     Press clipping dated 6/28/1950
# 6866                      Lt. Col. R.S. Hunt, pp. 80-81
# 6867  Lt. Col. R.S. Hunt of the Royal Army Medical Corp
# 6868                            Lt.Col. R.S. Hunt, p.79
# 6869                       B.W. Coad & L.A.J. Al-Hassan
# 6870                                          G.F. Mead
# 6871                                          G.F. Mead
# 6872                                          G.F. Mead
# 6873                                           G. Llano
# 6874                      Massillon Independent, 3/1905
# 6875  G.A. Llano in Airmen Against the Sea, p.69; V....
# 6876                       V.M. Coppleson (1962), p.257
# 6877                      Massillon Independent, 3/1905
# 6878                      A. De Maddalena; Anon. (1938)
# 6879                                   M. N. Kalafatas
# 6880                                    Mitchell-Hedges
# 6881                                          H. Capper
# 6882                                 G. Van Grevelynghe
# 6883              L. Green in Tavern of the Seas, p.182
# 6884                     Adelaide Advertiser, 1/11/1940
# 6885        L. Green in South African Beachcomber, p.97
# 6886                       V.M. Coppleson (1958), p.241
# 6887                                     T. Helm, p.219
# 6888                  Daily Kennebec Journal, 3/27/1911
# 6889  Captain A. Anderson,  Natal Mercury, 12/31/192...
# 6890  Captain A. Anderson,  Natal Mercury, 12/31/192...
# 6891  Fijian Society papers presented April 17, 1918...
# 6892     C. Creswell, GSAF; Wilmington Star, 7/17/1916
# 6893                       Rural New Yorker, 7/19/1913
# 6894                        Rural New Yorker, 7/19/1913
# 6895          Ref. J. T. Dubois in N.Y. Sun, 3/19/1911
# 6896                                   Captain W. Young
# 6897  NY Sun, 9/9/1906, referring to account by Loui...
# 6898  NY Sun, 9/9/1906, referring to account by Loui...
# 6899  NY Sun, 9/9/1906, referring to account by Loui...
# 6900  L. Becke in New York Sun, 9/9/1906; L. Schultz...
# 6901                   H. Taunton; N. Bartlett,  p. 234
# 6902              H. Taunton; N. Bartlett,  pp. 233-234
# 6903               F. Schwartz, p.23; C. Creswell, GSAF
# 6904                                The Sun, 10/20/1938
# 6905                                         S.W. Baker

# %%
sharks_df.isna().sum()
# Out:
# date           0
# year           2
# type          18
# country       50
# state        481
# location     564
# activity     584
# name         219
# sex          579
# age         2986
# injury        35
# time        3518
# species     3120
# source        19
# dtype: int64

# %%
#fixing gender

# %%
sharks_df['sex'].value_counts()
# Out:
# M     5552
# F      768
# N        3
# M        2
#  M       1
# .        1
# Name: sex, dtype: int64

# %%
gender_mapping = {
    'M':'M',
    'N':'N',
    'lli':'N',
    'M x 2':'M',    
    ' M':'M',
    '.':'N'
}

sharks_df['sex'] = sharks_df['sex'].replace(gender_mapping)

# %%
sharks_df['sex'].value_counts()
# Out:
# M    5555
# F     768
# N       4
# Name: sex, dtype: int64

# %%
sharks_df['sex'].fillna('N',inplace=True) #fill the empty values with N = not defined

# %%
sharks_df['sex'].value_counts()
# Out:
# M    5555
# F     768
# N     583
# Name: sex, dtype: int64

# %%
#country

# %%
sharks_df.isna().sum()
# Out:
# date           0
# year           2
# type          18
# country       50
# state        481
# location     564
# activity     584
# name         219
# sex            0
# age         2986
# injury        35
# time        3518
# species     3120
# source        19
# dtype: int64

# %%
country_series = pd.read_csv(url, usecols=["Country"])
country_series.value_counts(ascending=False).head(60)
# Out:
# Country
# USA                     2533
# AUSTRALIA               1468
# SOUTH AFRICA             596
# NEW ZEALAND              142
# PAPUA NEW GUINEA         136
# BAHAMAS                  133
# BRAZIL                   122
# MEXICO                    99
# ITALY                     72
# FIJI                      67
# NEW CALEDONIA             65
# PHILIPPINES               63
# REUNION                   60
# EGYPT                     48
# MOZAMBIQUE                46
# SPAIN                     46
# CUBA                      46
# INDIA                     40
# FRENCH POLYNESIA          37
# JAPAN                     36
# CROATIA                   35
# PANAMA                    32
# SOLOMON ISLANDS           30
# JAMAICA                   30
# IRAN                      29
# ENGLAND                   25
# INDONESIA                 24
# HONG KONG                 24
# GREECE                    24
# COSTA RICA                18
# PACIFIC OCEAN             17
# ATLANTIC OCEAN            17
# BERMUDA                   16
# VIETNAM                   15
# TONGA                     15
# VANUATU                   14
# SRI LANKA                 14
# CANADA                    13
# MARSHALL ISLANDS          13
# FRANCE                    13
# TURKEY                    12
# THAILAND                  12
# IRAQ                      12
# SOUTH ATLANTIC OCEAN      12
# ECUADOR                   11
# UNITED KINGDOM            11
# VENEZUELA                 11
# SENEGAL                   11
# KENYA                     10
# MAURITIUS                 10
# NEW GUINEA                10
# COLUMBIA                  10
# SEYCHELLES                 9
# TAIWAN                     9
# CHINA                      9
# SAMOA                      9
# SIERRA LEONE               8
# TANZANIA                   8
# ISRAEL                     8
# CHILE                      8
# dtype: int64

# %%
sharks_df['country'].value_counts()
# Out:
# USA                               2533
# AUSTRALIA                         1468
# SOUTH AFRICA                       596
# NEW ZEALAND                        142
# PAPUA NEW GUINEA                   136
#                                   ...
# ADMIRALTY ISLANDS                    1
# FEDERATED STATES OF MICRONESIA       1
# South Africa                         1
# RED SEA                              1
# CEYLON (SRI LANKA)                   1
# Name: country, Length: 223, dtype: int64

# %%
sharks_df['country'] = sharks_df['country'].str.lower()

# %%
sharks_df['country']
# Out:
# 0                      usa
# 1                      usa
# 2                      usa
# 3                australia
# 4                      usa
#                ...
# 6901             australia
# 6902             australia
# 6903                   usa
# 6904                panama
# 6905    ceylon (sri lanka)
# Name: country, Length: 6906, dtype: object

# %%
sharks_df['country'].value_counts(20)
# Out:
# usa                               0.369457
# australia                         0.214119
# south africa                      0.087077
# new zealand                       0.020858
# papua new guinea                  0.019837
#                                     ...
# red sea / indian ocean            0.000146
# british west indies               0.000146
# admiralty islands                 0.000146
# federated states of micronesia    0.000146
# ceylon (sri lanka)                0.000146
# Name: country, Length: 216, dtype: float64

# %%
sharks_df['country'].duplicated().sum()
# Out:
# 6689

# %%
sharks_df['href formula'].nunique()

# %%
sharks_df.isna().any()

# %%
sharks_df.isna().sum()

# %%
sharks_df['href formula'].isnull()

# %%
sharks_df['href formula'].value_counts(-50)

# %%
sharks_df['pdf'].nunique()

# %%
sharks_df['pdf'].isnull()

# %%
sharks_df['pdf'].value_counts(50)

# %%
gender_series = pd.read_csv(url, usecols=["Sex"])
gender_series

# %%
gender_series.value_counts(normalize=True, ascending=False).head(20)

# %%
sharks_df.shape

# %%
sharks_df.info()

# %%
sharks_df.nunique()

# %%
list(sharks_df.columns)

# %%
location_series = pd.read_csv(url, usecols=["Location"])
location_series

# %%
location_series.value_counts(ascending=False).head(60)

# %%
activity_series = pd.read_csv(url, usecols=["Activity"])
activity_series

# %%
activity_series.value_counts(ascending=False).head(60)

# %%
time_series = pd.read_csv(url, usecols=["Time"])
time_series

# %%
time_series.value_counts(ascending=False).head(60)

# %%
age_series = pd.read_csv(url, usecols=["Age"])
age_series

# %%
age_series.value_counts(normalize=True,ascending=False).head(60)

# %%
country_series = pd.read_csv(url, usecols=["Country"])
country_series.value_counts(ascending=False).head(60)

# %%
country_series.value_counts(normalize=True,ascending=False).head(60)

# %%
injury_series = pd.read_csv(url, usecols=["Injury"])
injury_series.value_counts(ascending=False).head(60)

# %%
sharks_df[["Activity", "Injury"]].head(60)
